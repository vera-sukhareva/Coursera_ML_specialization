# %%
import scipy.stats as sts
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Calculate a few first moments:
a = 2
# mean, var, skew, kurt = sts.gamma.stats(a, moments='mvsk')

# %%
r.mean()
# Out:
# 1.9445564782291829

# %%
r = sts.gamma.rvs(a, size=1000)

# %%
x = np.linspace(0,10, 1000)

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(x, sts.gamma.pdf(x, a),'r-', lw=2, label='gamma pdf')
ax.hist(r, density=True, histtype='stepfilled', alpha=0.5,label='frozen pdf')
ax.legend(loc='best', frameon=False)
plt.show()

# %%
fig, ax = plt.subplots(1, 1)
x = np.linspace(gamma.ppf(0.01, a),
                gamma.ppf(0.99, a), 1000)
ax.plot(x, gamma.pdf(x, a),
       'r-', lw=2, label='gamma pdf')

ax.hist(r, density=True, histtype='stepfilled', alpha=0.5,label='frozen pdf')
ax.legend(loc='best', frameon=False)
plt.show()

# %%
norm_rv = pd.DataFrame(sts.norm.rvs(a, size=1000), columns=['Norm'])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-260c6b19b052> in <module>
# ----> 1 pdf = norm_rv.pdf(x)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'pdf'

# %%
# n = 3
means_3 = []
x = np.linspace(-5,10, 1000)
for i in range(1000): 
    r3 = sts.gamma.rvs(a, size=3)
    means_3.append(r3.mean())
# df = pd.DataFrame(means_3, columns=['KDE'])
# ax = df.plot(kind='hist')
plt.hist(means_3, lw=2, label='gamma pdf')

norm_rv = sts.norm(np.array(means_3).mean(), a)
pdf = norm_rv.pdf(x)
plt.plot(x, pdf, label='theoretical pdf')
# plt.hist(norm)
plt.show()

# %%
plt.plot(x, pdf, label='theoretical pdf')
# plt.hist(norm)
plt.show()

# %%
pdf
# Out:
# array([1.23605776e-01, 1.24210951e-01, 1.24815961e-01, 1.25420777e-01,
#        1.26025367e-01, 1.26629699e-01, 1.27233742e-01, 1.27837464e-01,
#        1.28440833e-01, 1.29043817e-01, 1.29646384e-01, 1.30248502e-01,
#        1.30850139e-01, 1.31451261e-01, 1.32051838e-01, 1.32651835e-01,
#        1.33251221e-01, 1.33849961e-01, 1.34448025e-01, 1.35045377e-01,
#        1.35641986e-01, 1.36237817e-01, 1.36832839e-01, 1.37427016e-01,
#        1.38020316e-01, 1.38612705e-01, 1.39204149e-01, 1.39794616e-01,
#        1.40384070e-01, 1.40972478e-01, 1.41559806e-01, 1.42146021e-01,
#        1.42731087e-01, 1.43314972e-01, 1.43897641e-01, 1.44479059e-01,
#        1.45059192e-01, 1.45638007e-01, 1.46215469e-01, 1.46791543e-01,
#        1.47366195e-01, 1.47939391e-01, 1.48511096e-01, 1.49081276e-01,
#        1.49649896e-01, 1.50216922e-01, 1.50782319e-01, 1.51346053e-01,
#        1.51908089e-01, 1.52468394e-01, 1.53026931e-01, 1.53583667e-01,
# ...

# %%
# n = 5
means_5 = []
norm_rv = sts.norm(0, a)
x = np.arange(0,1000)
for i in range(1000): 
    r5 = gamma.rvs(a, size=5)
    means_5.append(r5.mean())
df = pd.DataFrame(means_5, columns=['KDE'])
ax = df.plot(kind='hist')

# %%
# n = 5
means_30 = []
norm_rv = sts.norm()
x = np.arange(0,1000)
for i in range(1000): 
    r30 = gamma.rvs(a, size=30)
    means_30.append(r30.mean())
df = pd.DataFrame(means_30, columns=['KDE'])
ax = df.plot(kind='hist')

mu = np.array(means_30).mean()
var = 0
for el in means_30:
    var += (el-mu)**2
var = var/len(means_30)
sigma = np.sqrt(var)
normRv = sts.norm(x, a)    
# x = np.linspace(0,1,1000)
pdf = normRv.pdf(x)
plt.plot(x, pdf)

# %%
var
# Out:
# 247513.02838249

# %%
print(np.var(means_30))
# Out:
# 0.06678294174726626

# %%
x = np.linspace(-4,4,100)
pdf = norm_rv.pdf(x)
plt.plot(x, pdf, label='theoretical pdf', alpha=0.5)
